# %% [markdown]
# IRIS
#
# TITANIC
#
# TIPS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snr

# %%
iris=snr.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
titanic=snr.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#line graph
ax=iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X_Axis')
ax.set_ylabel('Y_Axis')
# Out:
# Text(0, 0.5, 'Y_Axis')

# %%
#drop species column
df=iris.drop(['species'],axis=1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
#bar graph
df.plot(kind='bar')

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot(kind='barh')

# %%
df.iloc[0:5].plot(kind='bar')

# %%
#histogram
df.plot.hist()

# %%
df.diff().plot(kind='hist',stacked=True,bins=200)

# %%
df['sepal_width'].diff().plot(kind='hist',stacked=True,bins=200)

# %%
df['sepal_length'].diff().plot(kind='hist',stacked=True,bins=200)

# %%
df['petal_length'].diff().plot(kind='hist',stacked=True,bins=200)

# %%
df['petal_width'].diff().plot(kind='hist',stacked=True,bins=200)

# %%
#pie chart
d_new=df.iloc[0]

# %%
d_new
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d_new.plot.pie(figsize=(10,10))

# %%
d=df.iloc[0:4]

# %%
d
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2

# %%
d.plot.pie(subplots=True,figsize=(20,20),fontsize=15,autopct='%.4f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f18711dab90>,
# ...
#       dtype=object)

# %%
d.plot.pie(subplots=True,figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f1872195c90>,
# ...
#       dtype=object)

# %%
#scatter plot
df.plot.scatter(x='sepal_length',y='petal_length')

# %%
df.plot.scatter(x='petal_length',y='petal_width',color='r')

# %%
df.plot.scatter(x='sepal_length',y='sepal_width',color='g')

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')

# %%
df.diff().hist(color='g',alpha=0.8,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f187003fd50>,
# ...
#       dtype=object)
