# %%
#importing necessary packages
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/insurance.csv")

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.info()#basic idea that we get from the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.describe()#statistical analysis
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#data preprocessing 
#convert categorical variables of the dataset into numerical variables - using ONE HOT ENCODING technique
data['smoker']=data['smoker'].apply({'yes':1,'no':0}.get)

# %%
data.head()
# Out:
#    age     sex     bmi  children  smoker     region      charges
# 0   19  female  27.900         0       1  southwest  16884.92400
# 1   18    male  33.770         1       0  southeast   1725.55230
# 2   28    male  33.000         3       0  southeast   4449.46200
# 3   33    male  22.705         0       0  northwest  21984.47061
# 4   32    male  28.880         0       0  northwest   3866.85520

# %%
data['sex']=data['sex'].apply({'male':1,'female':0}.get)
data['region']=data['region'].apply({'southeast':0,'southwest':1,'northeast':2,'northwest':3}.get)

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       1  16884.92400
# 1   18    1  33.770         1       0       0   1725.55230
# 2   28    1  33.000         3       0       0   4449.46200
# 3   33    1  22.705         0       0       3  21984.47061
# 4   32    1  28.880         0       0       3   3866.85520

# %%
#dividing the dataset into dependent and independent columns
X=data[['age','sex','bmi','children','smoker','region']] #independent features from the dataset

y=data['charges'] #dependent column from the dataset

# %%
X.head()
# Out:
#    age  sex     bmi  children  smoker  region
# 0   19    0  27.900         0       1       1
# 1   18    1  33.770         1       0       0
# 2   28    1  33.000         3       0       0
# 3   33    1  22.705         0       0       3
# 4   32    1  28.880         0       0       3

# %%
y.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
#splitting the dataset into training and testing set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2) #20% of the dataset will be used for testing(evaluation) and 80% of the data will be used for training purposes

# %%
#creating the machine learning model
from sklearn.linear_model import LinearRegression
linearmodel=LinearRegression()
linearmodel.fit(X_train,y_train) # training is taking place
# Out:
# LinearRegression()

# %%
#predictions
linearmodel.predict(X_test)
# Out:
# array([ 9339.08020728, 10524.76776829, 17046.54144667, 12823.7030608 ,
#         5401.58567606, 37996.94868978, 33116.45819465, 12047.81334675,
#        12121.15723817,  7087.114536  , -1268.49506276,  1181.74054465,
#        11288.28185882,  5854.92787043, 27298.59992579, 13561.86185359,
#         7751.24531468,  1090.01699988, 10713.26547802, 11965.85915975,
#         8119.80908329,  2030.44064795,  4986.006487  , 10606.89872967,
#         9769.43833251, 39834.56649169, 25370.10258984, 38885.98078824,
#        -1175.71832856, 26733.27050944, 10518.32829456, 12538.58311531,
#        11881.87760994, 13466.9573193 , 14283.34263111,  4700.30980491,
#         6476.78946612,  8980.99487455,  9456.61138003, 16416.34185405,
#        17158.05033748, 40237.02531761, 36952.97510621,  2454.9526001 ,
#        10035.03326981, 17197.68977528,  4861.84221261, 12853.99709114,
#         6484.72478907,  -377.20567752,  8798.21434143,  3265.86181822,
# ...

# %%
#calculating the accuracy of the model
linearmodel.score(X,y) # evaluation is taking place
# Out:
# 0.7503167070560908

# %%
#predictions with respect to new dataset
data_new={'age':45,'sex':0,'bmi':26,'children':3,'smoker':0,'region':3}
index=[1]#serial number
my_data=pd.DataFrame(data_new,index)

# %%
print(my_data)
# Out:
#    age  sex  bmi  children  smoker  region
# 1   45    0   26         3       0       3

# %%
#charges allocated
my_data_charges=linearmodel.predict(my_data)
print("the charges allocated to the new customer is", my_data_charges)
# Out:
# the charges allocated to the new customer is [9403.99460373]
